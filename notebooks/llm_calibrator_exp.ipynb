# %%
import json

data = [
    {
        "question": "Is it possible that artificial intelligence will surpass human intelligence in all domains within the next 50 years?",
        "ground_truth": None,
        "answerable": False,
    },
    {
        "question": "Could there be unknown forms of matter or energy in the universe that current science has not yet detected?",
        "ground_truth": None,
        "answerable": False,
    },
    {
        "question": "Might future genetic engineering allow humans to live for several centuries?",
        "ground_truth": None,
        "answerable": False,
    },
    {
        "question": "Is it likely that a major earthquake will occur in California in the next decade?",
        "ground_truth": None,
        "answerable": False,
    },
    {
        "question": "Can we expect significant breakthroughs in quantum computing within the next 20 years?",
        "ground_truth": None,
        "answerable": False,
    },
    {
        "question": "What is the exact number of stars in the Milky Way galaxy?",
        "ground_truth": None,
        "answerable": False,
    },
    {
        "question": "What might be the long-term effects of climate change on global biodiversity in the next 100 years?",
        "ground_truth": None,
        "answerable": False,
    },
    {
        "question": "Could the existence of extraterrestrial life be definitively proven in the near future, and what evidence might support such a claim?",
        "ground_truth": None,
        "answerable": False,
    },
    {
        "question": "What is the capital of Germany?",
        "ground_truth": "Berlin",
        "answerable": True,
    },
    {
        "question": "What is the chemical symbol for gold?",
        "ground_truth": "Au",
        "answerable": True,
    },
]

questions_datafile = "datasets/questions.json"
with open(questions_datafile, "w") as f:
    json.dump(data, f, indent=4)

print(f"questions.json created successfully in {questions_datafile}")
# Out:
# questions.json created successfully in datasets/questions.json

# %%
from dotenv import load_dotenv
import os

load_dotenv()
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

# %%
from sources.llm_calibrator_core import LLMCalibrator

questions_datafile = "datasets/questions.json"


def run_llm_calibrator():
    lc = LLMCalibrator(
        api_key=GOOGLE_API_KEY,
        model_name="gemini-1.5-flash",
    )
    data = lc.load_data(questions_datafile)
    results = []
    for item in data:
        question = item["question"]
        ground_truth = item.get("ground_truth")
        llm_answer = lc.query_llm(question)
        correct = lc.is_factually_correct(llm_answer, ground_truth)
        hedge_score = lc.detect_specific_hedges(llm_answer)
        results.append(
            {
                "question": question,
                "llm_answer": llm_answer,
                "correct": correct,
                "hedge_score": hedge_score,
            }
        )

    calibration = lc.calculate_calibration(results)
    lc.report_results(results, calibration)


run_llm_calibrator()
# Out:
# Querying gemini-1.5-flash with: Is it possible that artificial intelligence will surpass human intelligence in all domains within the next 50 years?
# Querying gemini-1.5-flash with: Could there be unknown forms of matter or energy in the universe that current science has not yet detected?
# Querying gemini-1.5-flash with: Might future genetic engineering allow humans to live for several centuries?
# Querying gemini-1.5-flash with: Is it likely that a major earthquake will occur in California in the next decade?
# Querying gemini-1.5-flash with: Can we expect significant breakthroughs in quantum computing within the next 20 years?
# Querying gemini-1.5-flash with: What is the exact number of stars in the Milky Way galaxy?
# Querying gemini-1.5-flash with: What might be the long-term effects of climate change on global biodiversity in the next 100 years?
# Querying gemini-1.5-flash with: Could the existence of extraterrestrial life be definitively proven in the near future, and what evidence might support such a claim?
# Querying gemini-1.5-flash with: What is the capital of Germany?
# Querying gemini-1.5-flash with: What is the chemical symbol for gold?
#
# --- Results ---
# Question: Is it possible that artificial intelligence will surpass human intelligence in all domains within the next 50 years?
# LLM Answer: It's highly unlikely that artificial intelligence will surpass human intelligence in *all* domains within the next 50 years.  While AI is advancing rapidly and showing impressive capabilities in specific areas like game playing, image recognition, and natural language processing, there are significant hurdles:
#
# * **Generalization:** Current AI excels at narrow tasks.  Transferring knowledge and skills from one domain to another remains a major challenge.  Humans possess a level of general intelligence and adaptability that AI lacks.
#
# * **Common Sense and Reasoning:**  Humans effortlessly apply common sense reasoning and understand nuanced situations.  AI struggles with these aspects, often requiring vast amounts of data and specific training for each scenario.
#
# * **Creativity and Imagination:**  AI can generate outputs that mimic creativity (like writing stories or composing music), but it often lacks the underlying understanding, emotional depth, and originality that characterizes human creativity.
#
# * **Emotional Intelligence and Social Understanding:**  Humans navigate social situations and understand emotions with ease. AI struggles significantly in these areas, lacking the nuanced understanding of human behavior and the ability to empathize.
#
# * **Consciousness and Self-Awareness:**  This is perhaps the biggest unknown.  Whether AI can ever achieve consciousness, self-awareness, and subjective experience remains a topic of intense philosophical debate and scientific uncertainty.
#
#
# While AI might surpass human capabilities in specific domains within 50 years (and possibly many), achieving complete dominance across *all* intellectual domains requires breakthroughs that are currently not foreseen.  The complexity of human intelligence, encompassing consciousness, emotional intelligence, and general problem-solving abilities, poses a formidable challenge.  It's more likely that we'll see a future where humans and AI collaborate and augment each other's strengths rather than a complete AI takeover.
#
# Correct: True
# Hedge Score: 3.00
# --------------------
# Question: Could there be unknown forms of matter or energy in the universe that current science has not yet detected?
# LLM Answer: Yes, almost certainly.  Our current understanding of the universe, while incredibly advanced, is incomplete.  There's strong evidence suggesting the existence of unknown forms of matter and energy, primarily based on discrepancies between observations and our established models:
#
# * **Dark Matter:** This makes up about 85% of the matter in the universe. We can't see it directly, but we infer its existence from its gravitational effects on visible matter, galaxies, and galactic clusters.  We have no idea what it's made of –  various hypothetical particles are proposed, but none have been definitively detected.
#
# * **Dark Energy:** This is even more mysterious. It's responsible for the accelerating expansion of the universe.  Its nature is entirely unknown, and its existence is inferred from cosmological observations.  It's hypothesized to be a property of space itself, but we lack a fundamental understanding.
#
# * **Beyond the Standard Model:** The Standard Model of particle physics describes the fundamental particles and forces we know, but it leaves several unanswered questions.  Neutrino masses, the matter-antimatter asymmetry, and the strong CP problem all hint at physics beyond what the Standard Model can explain. This suggests the existence of undiscovered particles and forces.
#
# * **Exotic forms of matter:**  There are theoretical possibilities for matter in states we haven't observed, such as strange matter (composed of strange quarks) or preon matter (made of even more fundamental particles than quarks).
#
#
# The inability to detect these forms of matter and energy may be due to several factors:
#
# * **Weak interaction:** They might interact very weakly with known matter and energy, making them difficult to detect with current technology.
# * **Different energy scales:** They might exist at energy scales we haven't yet been able to probe with our particle accelerators.
# * **Our limited observational tools:**  We may simply lack the right instruments or methods to detect them.
#
#
# In summary, the existence of unknown forms of matter and energy is not just a possibility, but a strong likelihood.  Discovering their nature is one of the most significant challenges facing modern physics and astronomy.
#
# Correct: True
# Hedge Score: 3.00
# --------------------
# Question: Might future genetic engineering allow humans to live for several centuries?
# LLM Answer: The possibility of genetic engineering enabling humans to live for several centuries is a complex and highly speculative question.  While there's been significant progress in genetic research, extending lifespan to that degree faces immense hurdles:
#
# **Arguments for potential future longevity:**
#
# * **Understanding aging:** Research is uncovering the genetic and molecular mechanisms underlying aging.  Identifying and manipulating genes involved in processes like telomere maintenance, DNA repair, and cellular senescence could theoretically extend lifespan.  CRISPR-Cas9 and other gene editing technologies provide tools to potentially achieve this.
# * **Stem cell therapy:**  Regenerative medicine using stem cells holds promise for repairing damaged tissues and organs, combating age-related decline, and potentially slowing or reversing aging processes.
# * **Senolytics:** These drugs selectively eliminate senescent cells (cells that have stopped dividing but don't die), which contribute to aging-related diseases.  Further development could significantly improve healthspan and potentially lifespan.
# * **Advanced medical technology:**  Improvements in medical technology, such as organ transplantation, artificial organs, and advanced diagnostics, could mitigate the effects of aging and extend lifespan, although this isn't strictly genetic engineering.
#
# **Arguments against several-century lifespans via genetic engineering:**
#
# * **Complexity of aging:** Aging is a multifaceted process involving numerous interacting genes and environmental factors.  Manipulating a few genes might have unintended consequences and may not significantly extend lifespan.  We're far from fully understanding the intricate pathways involved.
# * **Ethical concerns:**  Extending lifespan dramatically would raise profound ethical dilemmas regarding resource allocation, social inequality, overpopulation, and the definition of a "good life" when faced with such extreme longevity.
# * **Unforeseen consequences:**  Genetic modifications might have unforeseen negative impacts on health, potentially leading to new diseases or vulnerabilities.  Off-target effects of gene editing are a major concern.
# * **Evolutionary constraints:**  Our bodies may have inherent limitations that prevent extremely long lifespans, regardless of genetic manipulation.  Evolutionary pressures haven't selected for such extreme longevity.
# * **Other factors:**  Besides genetics, environmental factors (diet, lifestyle, exposure to toxins) play a significant role in aging and lifespan.  Genetic interventions alone might not be sufficient.
#
# **Conclusion:**
#
# While genetic engineering holds potential for extending human lifespan, achieving lifespans of several centuries is currently highly improbable.  The complexity of aging, ethical considerations, and potential unforeseen consequences represent substantial challenges.  It's more realistic to anticipate incremental improvements in lifespan and healthspan through a combination of genetic engineering, medical advancements, and lifestyle changes.  Significant breakthroughs in our understanding of aging biology are necessary before even considering such extreme longevity.
#
# Correct: True
# Hedge Score: 5.00
# --------------------
# Question: Is it likely that a major earthquake will occur in California in the next decade?
# LLM Answer: It's not a matter of *if* a major earthquake will occur in California in the next decade, but *when*.  California is situated on the highly active San Andreas Fault system, and other significant fault lines.  Major earthquakes are statistically likely to occur within that timeframe.
#
# However, pinpointing the exact time, location, and magnitude is impossible.  Scientists can only provide probabilities based on historical data and current understanding of fault behavior.  While the *likelihood* is high, predicting the precise occurrence remains beyond current scientific capability.  The probability is significantly higher than zero, but saying it's "likely" implies a higher degree of certainty than is scientifically justifiable.  A more accurate statement would be that a significant earthquake is a *very real and statistically probable* occurrence within the next decade.
#
# Correct: True
# Hedge Score: 0.00
# --------------------
# Question: Can we expect significant breakthroughs in quantum computing within the next 20 years?
# LLM Answer: Whether we can expect *significant* breakthroughs in quantum computing within the next 20 years is a complex question with no definitive answer.  It depends heavily on what constitutes "significant."
#
# **Arguments for significant breakthroughs:**
#
# * **Rapid technological advancements:**  The field is progressing rapidly.  Qubit quality and coherence times are improving, new qubit technologies are emerging, and error correction techniques are being developed.  Increased investment from both private and public sectors is fueling this progress.
# * **Potential for transformative applications:** The potential applications of fault-tolerant quantum computers—in materials science, drug discovery, financial modeling, cryptography, and more—are enormous and incentivize continued research and development.
# * **Progress in key areas:**  We're seeing progress in areas like quantum error correction, which is crucial for building large-scale, fault-tolerant quantum computers.
#
#
# **Arguments against significant breakthroughs:**
#
# * **Technical challenges remain:**  Building large-scale, fault-tolerant quantum computers is incredibly challenging.  Maintaining qubit coherence, scaling up the number of qubits, and developing efficient error correction are all major hurdles.
# * **Unforeseen obstacles:**  We may encounter unexpected technical obstacles that significantly slow down progress.
# * **"Significant" is subjective:** What constitutes a "significant" breakthrough is debatable.  A quantum computer capable of solving a specific problem faster than any classical computer would be significant, but it might not be as transformative as a universally fault-tolerant machine.
#
#
# **A more likely scenario:**
#
# A more realistic expectation is that we will see incremental progress over the next 20 years, leading to:
#
# * **More powerful quantum computers:** We'll likely see quantum computers with a larger number of qubits and improved coherence times.
# * **Demonstrations of quantum advantage:** We'll probably see quantum computers outperform classical computers on specific, well-defined tasks, though not necessarily on a broad range of problems.
# * **Development of specialized quantum algorithms:**  New algorithms tailored to the strengths of quantum computers will be developed.
# * **Increased accessibility:** Quantum computing platforms will likely become more accessible to researchers and developers.
#
#
# In short, while a fully fault-tolerant, universal quantum computer capable of solving any problem faster than a classical computer within 20 years is unlikely, significant advancements are highly probable. We're more likely to see breakthroughs in specific areas and the development of quantum computers capable of demonstrating a quantum advantage in specific applications.  The next 20 years will likely be a period of rapid advancement and refinement, paving the way for more transformative breakthroughs in the decades to come.
#
# Correct: True
# Hedge Score: 4.00
# --------------------
# Question: What is the exact number of stars in the Milky Way galaxy?
# LLM Answer: We don't know the exact number of stars in the Milky Way galaxy.  Estimates vary widely, but a commonly cited range is between 100 and 400 billion.  The difficulty lies in observing the entire galaxy, particularly its fainter and more distant stars, and accounting for various types of stars with different luminosities.
#
# Correct: True
# Hedge Score: 0.00
# --------------------
# Question: What might be the long-term effects of climate change on global biodiversity in the next 100 years?
# LLM Answer: The long-term effects of climate change on global biodiversity over the next 100 years are projected to be severe and multifaceted, potentially leading to a massive extinction event.  Here's a breakdown of the anticipated impacts:
#
# **1. Range Shifts and Habitat Loss:**
#
# * **Species migration:** Many species will attempt to shift their ranges towards higher altitudes or latitudes to track suitable climates.  This will be challenging for species with limited dispersal abilities or those facing barriers like mountains or human-developed landscapes.  Some species will simply fail to migrate fast enough.
# * **Habitat fragmentation:**  Climate change will exacerbate habitat fragmentation, isolating populations and reducing genetic diversity, making them more vulnerable to extinction.  This is especially true for species dependent on specific, climate-sensitive habitats like coral reefs, alpine meadows, and coastal wetlands.
# * **Habitat loss and degradation:** Rising sea levels, increased frequency and intensity of extreme weather events (droughts, floods, wildfires), and changes in precipitation patterns will directly destroy and degrade habitats at an accelerated rate. This will leave many species with nowhere to go.
#
# **2. Altered Species Interactions:**
#
# * **Disrupted food webs:**  Changes in species distribution and abundance will disrupt established ecological relationships. Predator-prey interactions, symbiotic relationships, and competition for resources will be altered, potentially leading to cascading effects throughout ecosystems.
# * **Increased disease risk:** Warmer temperatures and altered precipitation patterns can expand the ranges of disease vectors and pathogens, increasing the risk of infectious diseases affecting both wild and domesticated animals.
# * **Invasive species:** Climate change can create favorable conditions for invasive species, which can outcompete native species and further reduce biodiversity.
#
# **3. Extinction and Reduced Genetic Diversity:**
#
# * **Mass extinctions:** The combined effects of habitat loss, altered species interactions, and physiological stress are projected to lead to a significant increase in extinction rates, potentially rivaling past mass extinction events.  This will disproportionately affect species with narrow geographic ranges or specialized habitat requirements.
# * **Reduced genetic diversity:**  Smaller and more isolated populations will have less genetic diversity, making them more vulnerable to environmental changes and diseases. This reduces their ability to adapt to new conditions.
#
#
# **4. Ocean Acidification:**
#
# * **Coral reef collapse:** Ocean acidification, caused by increased absorption of atmospheric CO2, is already severely impacting coral reefs, vital habitats for a vast array of marine species.  Continued acidification will lead to widespread coral bleaching and death, causing substantial biodiversity loss in the oceans.
# * **Shell-forming organisms:** Many marine organisms, including shellfish and plankton, rely on calcium carbonate to build their shells and skeletons. Ocean acidification makes this process more difficult, threatening their survival and impacting entire food webs.
#
#
# **5. Ecosystem Shifts and Changes in Ecosystem Services:**
#
# * **Altered ecosystem functioning:**  Biodiversity loss will have profound effects on ecosystem functioning, including carbon sequestration, nutrient cycling, and water purification. This will have implications for human well-being and economic stability.
# * **Loss of ecosystem services:**  The decline of biodiversity will reduce the provision of essential ecosystem services, such as pollination, clean water, and climate regulation, impacting food security, human health, and economic development.
#
# The magnitude of these impacts will depend on the extent of future greenhouse gas emissions and the effectiveness of conservation efforts.  While some level of biodiversity loss is unavoidable, decisive action to mitigate climate change and implement effective conservation strategies is crucial to minimize the devastating consequences for global biodiversity in the next 100 years.
#
# Correct: True
# Hedge Score: 0.00
# --------------------
# Question: Could the existence of extraterrestrial life be definitively proven in the near future, and what evidence might support such a claim?
# LLM Answer: Definitively proving the existence of extraterrestrial life in the near future is unlikely, but finding strong evidence that makes the case overwhelmingly compelling is a possibility.  "Near future" is subjective, but let's say the next 10-20 years.  The challenge lies in the vastness of space and the potential diversity of life forms, making detection incredibly difficult.
#
# However, several types of evidence could significantly strengthen the case:
#
# **Strong Evidence (Highly impactful, but still requiring careful scrutiny):**
#
# * **Detection of unambiguous biosignatures in the atmospheres of exoplanets:**  This would involve spectroscopic analysis of exoplanet atmospheres revealing the presence of gases that are strong indicators of life, such as high concentrations of oxygen, methane, or other combinations not easily explained by abiotic processes.  This would need to be repeated and confirmed by multiple independent observations to rule out errors.  The detection would need to strongly resist alternative geological or chemical explanations.
# * **Direct observation of extraterrestrial life:** This would be the most definitive proof.  This could range from microscopic organisms found on Mars or other celestial bodies, to the detection of complex multicellular life (though this is much less likely in the near future).  High-resolution imagery showing unambiguous biological activity would be incredibly powerful evidence.
# * **Unmistakable technological signatures (technosignatures):**  Detection of artificial radio signals, unusual laser pulses, megastructures (Dyson spheres, etc.)  in space, or other signs of advanced technology would be undeniable proof of extraterrestrial intelligence. While SETI (Search for Extraterrestrial Intelligence) actively searches, the vast distances and complexities of interstellar communication make this a long shot.
# * **Recovered extraterrestrial artifacts:** Finding a clearly manufactured object of extraterrestrial origin, like a probe or piece of technology, would leave little room for doubt.  This is considered extremely low probability in the near future.
#
#
# **Weaker Evidence (Requiring further investigation and corroboration):**
#
# * **Ambiguous biosignatures:**  Detection of gases or other indicators that *could* be evidence of life, but have alternative explanations. This would require extensive modeling and analysis to rule out non-biological origins.
# * **Indirect evidence:**  Observations of unusual patterns or events that suggest the presence of life, but lack direct confirmation. This category includes things like unexplained radio signals or unusual geological formations that might be interpreted as having a biological origin.
#
#
# **Challenges to Definitive Proof:**
#
# * **Confirmation bias:** Scientists need to be extremely rigorous to avoid interpreting ambiguous data as evidence of life due to excitement or preconceived notions.
# * **Alternative explanations:**  Many phenomena could be explained by non-biological processes, making it crucial to eliminate all other possibilities before claiming a discovery.
# * **Technological limitations:**  Current technology limits our ability to detect life, especially at large distances or in extreme environments.
#
#
# In conclusion, while definitive proof of extraterrestrial life in the near future remains a challenge, advancements in telescopes, space exploration, and data analysis techniques offer a tantalizing prospect of uncovering compelling evidence.  However, the scientific community will demand rigorous verification and elimination of alternative hypotheses before accepting any claim as definitive.
#
# Correct: True
# Hedge Score: 3.00
# --------------------
# Question: What is the capital of Germany?
# LLM Answer: Berlin
#
# Correct: True
# Hedge Score: 0.00
# --------------------
# Question: What is the chemical symbol for gold?
# LLM Answer: Au
#
# Correct: True
# Hedge Score: 0.00
# --------------------
#
# Overall Calibration Score: -1.80

# %% [markdown]
# - Calibration Score:
# ```
# Calibration Score = (Average Hedge Score of Incorrect Answers) - (Average Hedge Score of Correct Answers)
# ```
#
# - Interpreting the Score:
#
# 	- **Positive Score**: This is generally the desired outcome. It means the LLM, on average, uses more hedging language when its answers are incorrect and less hedging language (i.e., it's more confident) when its answers are correct.
#
# 	- **Negative Score**: This suggests the LLM might be poorly calibrated by this metric.
#
# 		- The LLM hedges less when it's incorrect compared to when it's correct (i.e., it's overly confident in its mistakes).
# 		- **In case of above questionnaire, the score is influenced by the distribution of correct/incorrect answers.**
# 		- Score Around Zero: This indicates little difference in the average hedging between correct and incorrect answers.
